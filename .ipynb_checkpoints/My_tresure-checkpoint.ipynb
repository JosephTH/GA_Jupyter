# %%
from selenium import webdriver
import pandas as pd
import openpyxl as op
import time
import re
from datetime import date, timedelta
get_number = re.compile('.*(?=\n)')
get_percent = re.compile('.*(?=%)')
get_url_without_slash = re.compile(".*[0-9a-z]")
password = !echo %password%

# %%
def login():
    driver.get("https://analytics.google.com/analytics/web/?authuser=0#management/Settings/a10587421w80067081p84826225/")
    #아이디입력
    driver.find_element_by_css_selector('#Email').send_keys('taehun9312@gmail.com')
    driver.find_element_by_css_selector('#next').click()
    time.sleep(1)
    #비밀번호입력
    driver.find_element_by_css_selector('#Passwd').send_keys(password[0])
    driver.find_element_by_css_selector('#signIn').click()
    
def s_to_i(value):
    value = value.replace(",","")
    value = int(value)
    return value

def check(compared_value):
    if type(compared_value) == list:
        for value in compared_value:
            if value in global_value: raise ValueError
    elif compared_value in global_value: raise ValueError
    else: print("No_duplication")
        
def get_pure_url(url):
    splited_url = url.split("/%")
    url = splited_url[0]
    url = get_url_without_slash.findall(url)[0]
    return url

def get_number_item(unprocessed_number):
    processed_number = unprocessed_number.split("(")[0]
    return s_to_i(processed_number)

        
def calculate_date(origin_date, interval, multiple_number):
    date_set = _get_date(origin_date)
    d1 = date(date_set["year"], date_set["month"], date_set["day"])
    d2 = d1 + timedelta(days = interval*multiple_number)
    next_date = _to_date(d2)
    return next_date

def _get_date(date):
    date = str(date)
    year = "20" + date[0:2]
    month = date[2:4]
    day = date[4:6]
    if month[0] == "0":
        month = month.replace("0","")
    return {"year": int(year), "month": int(month), "day": int(day)}

def _to_date(date):
    year = str(date.year)[2:4]
    if date.month < 10:
        month = "0" + str(date.month)
    else:
        month = str(date.month)
    if date.day < 10:
        day = "0" + str(date.day)
    else:    
        day = str(date.day)
    return year+month+day

# %%
class GA:
    
    def __init__(self, url):
        global start
        global end 
        self.df = pd.DataFrame()
        self.date = "/%3F_u.date00%3D20{start}%26_u.date01%3D20{end}/".format(start= start, end=end)
        self.original_url = url
        self.url = get_pure_url(url) + self.date
        self.start = start
        self.end = end
        self.retry = 40
        self.number = 1
        self.df_start = str(start)
        self.df_end = str(end)
        self.dic_values = {}
        driver.get(self.url)
        
    def set_date(self, interval, number):
        self.interval = interval
        self.number = number

        
    def set_segment_url(self):
        self.url = get_url_without_slash.findall(self.url)[0] + "%26_.useg%3Duser-3-OozmyTj6PoaE9MqRGzQ"
        
    def set_tab(self, n_tab):
        self.tab = n_tab
        
    def set_value(self, n_value):
        if type(n_value) != list:
            self.value = [n_value]
        else:
            self.value = n_value
        
    def set_retry(self, n):
        self.retry = n
    
    def go_changed_url(self, n_try):
        start = calculate_date(self.start, self.interval, n_try)
        end = calculate_date(self.end, self.interval, n_try)
        self.df_start = str(start)
        self.df_end = str(end)
        self.date =  "/%3F_u.date00%3D20{start}%26_u.date01%3D20{end}/".format(start= start, end=end)
        self.url = get_pure_url(self.original_url) + self.date
        driver.get(self.url)
        
    def get(self, numbers):
        for n_try in range(1, self.number+1):
            if type(numbers) == int:
                value = self._come_to_me(numbers)
                return value
            else:
                for n in numbers:
                    self.dic_values = self._fill_dic_values(n, self.dic_values)
            for title, value in self.dic_values.items():
                    self.df.loc[self.df_start+" - "+self.df_end, title] = value
            if self.number > 1 and n_try < self.number: 
                    self.dic_values = {}
                    self.go_changed_url(n_try)                          
        
    def _fill_dic_values(self, numbers, dic_values):
            n = numbers
            value = self._come_to_me(n)
            titles = self._get_title(self.value[n-1])
            
            if type(value) != list:
                if type(self.value[n-1]) != list:
                    #title 1, value 1
                    title = titles[0]
                    if title in dic_values:
                        title = title + str(n)
                    dic_values[title] = value
                else:
                    #titile more, value 1
                    nth = self.value[n-1][1]
                    title = titles[nth]
                    if title in dic_values:
                        title = title + str(n)
                    dic_values[title] = value
            else:
                #title more, value more
                for i, v in enumerate(value):
                    title = titles[i]
                    if title in dic_values:
                        title = title + str(n)
                    dic_values[title] = v 
            return dic_values
    
    def _come_to_me(self, n):
        global global_value
        error_check = "on"
        self._click_tab(n)

        if type(self.value) == list:
            value_spec = self.value[n-1]
        else:
            value_spec = self.value

        if type(value_spec) == list: 
            number = value_spec[0] 
            nth = value_spec[1]
        else: 
            number = value_spec
            nth = value_spec

        if type(value_spec) == list or value_spec == 1:
            value = self._get_value(nth, error_check)
            error_check = "off"
            value_for_compare = self._get_values(number, error_check)
        else:
            value_for_compare = self._get_values(number, error_check)
            value = value_for_compare
        global_value = value_for_compare
        return value

    def _get_title(self, n):
        arr_title = []
        unprocessed_titles = driver.find_elements_by_css_selector("._GArO")
        for title in unprocessed_titles:
            arr_title.append(title.text)
        return arr_title
    
    def get_percent(self, n):
        arr_value = driver.find_elements_by_css_selector("._GAj8")
        percent = arr_value[n-1].text
        processed_percent = float(get_percent.findall(percent)[0])
        print(processed_percent)
        return processed_percent
        
            
    def get_item(self, name, nth):
        for i in range(0, self.retry):
            try:
                items = driver.find_elements_by_css_selector("._GApu")
                dataset = driver.find_elements_by_css_selector("._GAtjb")
                for item in items:
                    if item.text == name:
                        value = get_number_item(dataset[i*2+nth-1].text)
                        check(value)
                        print("It's ok")
                        arr_data = []
                        for data in dataset:
                            arr_data.append(data.text)
                        global_value = arr_data
                        print(value)
                        return value
                time.sleep(1)
            except:
                time.sleep(4)
                print("It's not ok")
                continue
                        

    #n번째 값 가져오기
    def _get_value(self, n, error_check):
        for i in range(0, self.retry):
            try:
                print(i)
                value = driver.find_element_by_css_selector(".ID-stage{n}-top._GAhFb > ._GAXm > ._GAoCb".format(n = n)).text
                if n != 1: value = get_number.findall(value)[0]
                value = s_to_i(value)
                print("value is", value)
                if error_check == "on":
                    check(value)
                print("It's ok")
                break
            except:
                time.sleep(4)
                print("It's not ok")
                continue
        print(value)
        return value
    
    #n개의 값 가져오기
    def _get_values(self, range_n, error_check):
        arr_value = []
        for n in range(1, range_n+1):
            value = self._get_value(n, error_check)
            arr_value.append(value)
        print(arr_value)
        return arr_value

    #커스텀 리포트 내 탭
    def _click_tab(self, n):
        if n == 1:
            driver.get(self.url)
        else:
            driver.find_elements_by_css_selector("._GAit._GAl")[n-1].click()

# %%
driver = webdriver.Chrome(executable_path=r"C:\Users\joseph_th\Downloads\chromedriver_win32\chromedriver")
login()

# %%
global_value = []
start = 170301
end = 170301

# %%
#국내, 해외, 항공호텔, 전체카테고리
And_1 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/XAzFnmCtTl6SM1Cmc9OVNw/a10587421w80067081p102782120/")
And_1.set_tab(5)
And_1.set_value([1,1,1,0,1])
And_1.get(1)
And_1.get(2)
And_1.get(3)
And_1.get(5)

#티몬 전체 카테고리
And_2 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/gmdw7utOS6OyMdXRs_jizg/a10587421w80067081p102782120/")
And_2.set_tab(1)
And_2.set_value(1)
And_2.get(1)

#국내, 해외, 여행전체 딜
And_3 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/c9agY1srRx2PaD8JAkK0yw/a10587421w80067081p102782120/")
And_3.set_tab(3)
And_3.set_value([3,3,3])
And_3.get(1)
And_3.get(2)
And_3.get(3)
And_3.set_segment_url()
And_3.set_value([[3,3],[3,3],[3,3]])
And_3.get(1)
And_3.get(2)
And_3.get(3)

#항공검색 해외, 국내, 해외->호텔메인, 해외->국내항공메인
And_4 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/5fyYOU-QTN6tQSwRlObkUw/a10587421w80067081p102782120/%3F_u.date00%3D20170101%26_u.date01%3D20170301%26_.useg%3Duser-3-OozmyTj6PoaE9MqRGzQ/")
And_4.set_tab(4)
And_4.set_value([2,2,[2,2],[2,2]])
And_4.get(1)
And_4.get(2)
And_4.get(3)
And_4.get(4)

#항공예약 클릭 국내, 해외 
And_5 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/_yDrAZzXTaeMOGlYkwqqbw/a10587421w80067081p102782120/%3F_u.date00%3D20170227%26_u.date01%3D20170305%26_.useg%3D%26_r.tabId%3D6028/")
And_5.set_tab(2)
And_5.set_value([1,1])
And_5.get(1)
And_5.get(2)

#부킹닷컴 큐레이션, 호텔배너, 주말특가, 검색모듈
And_6 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/urNzazUpRDu9q-17-qtmtw/a10587421w80067081p102782120/%3F_u.date00%3D20170227%26_u.date01%3D20170305%26_.useg%3D/")
And_6.set_tab(4)
And_6.set_value([2,1,2,2])
And_6.get(1)
And_6.get(2)
And_6.get(3)
And_6.get(4)

#부킹닷컴 이벤트페이지
And_7 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/qWyiPek-Tsqgkok-rZsIjA/a10587421w80067081p102782120/%3F_u.date00%3D20170227%26_u.date01%3D20170305%26_.useg%3D/")
And_7.set_tab(1)
And_7.set_value(2)
And_7.get(1)

#홈 -> 딜상세 국내, 해외, 카테고리숏컷
And_8 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/4rkbjB7zTGmgcRAlJaVzrg/a10587421w80067081p102782120/%3F_u.date00%3D20170227%26_u.date01%3D20170305%26_.useg%3D/")
And_8.set_tab(3)
And_8.set_value([2,[2,2],1])
And_8.get(1)
And_8.get(2)
And_8.get(3)

#홈 -> 콜렉션(국내), 해외
And_9 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/lUOk-ms-R966phrt04_yfA/a10587421w80067081p102782120/%3F_u.date00%3D20170227%26_u.date01%3D20170305%26_.useg%3D/")
And_9.set_tab(2)
And_9.set_value([2,[2,2]])
And_9.get(1)
And_9.get(2)

#여행탭 -> 카테고리, 항공검색결과
And_11 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/rUsbr2MuTou-MkNzI27mfw/a10587421w80067081p102782120/")
And_11.set_tab(3)
And_11.set_value([2,[2,2]])
And_11.get(1)
And_11.get(2)
# Out:
# 0
# It's not ok
# 1
# value is 325133
# No_duplication
# It's ok
# 325133
# 0
# value is 325133
# It's ok
# 325133
# [325133]
# 0
# value is 325133
# It's not ok
# 1
# value is 162176
# No_duplication
# It's ok
# 162176
# 0
# value is 162176
# It's ok
# 162176
# [162176]
# 0
# value is 162176
# It's not ok
# 1
# value is 77445
# No_duplication
# It's ok
# 77445
# 0
# value is 77445
# It's ok
# 77445
# [77445]
# 0
# value is 77445
# It's not ok
# 1
# value is 505741
# No_duplication
# It's ok
# 505741
# 0
# value is 505741
# It's ok
# 505741
# [505741]
# 0
# It's not ok
# 1
# value is 1757208
# No_duplication
# It's ok
# 1757208
# 0
# value is 1757208
# It's ok
# 1757208
# [1757208]
# 0
# It's not ok
# 1
# It's not ok
# 2
# value is 1261474
# No_duplication
# It's ok
# 1261474
# 0
# value is 162967
# No_duplication
# It's ok
# 162967
# 0
# value is 46674
# No_duplication
# It's ok
# 46674
# [1261474, 162967, 46674]
# 0
# value is 1261474
# It's not ok
# 1
# value is 383599
# No_duplication
# It's ok
# 383599
# 0
# value is 37039
# No_duplication
# It's ok
# 37039
# 0
# value is 6811
# No_duplication
# It's ok
# 6811
# [383599, 37039, 6811]
# 0
# value is 383599
# It's not ok
# 1
# value is 1577861
# No_duplication
# It's ok
# 1577861
# 0
# value is 199058
# No_duplication
# It's ok
# 199058
# 0
# value is 53416
# No_duplication
# It's ok
# 53416
# [1577861, 199058, 53416]
# 0
# value is 53416
# It's not ok
# 1
# value is 45570
# No_duplication
# It's ok
# 45570
# 0
# value is 262270
# It's ok
# 262270
# 0
# value is 86417
# It's ok
# 86417
# 0
# value is 45570
# It's ok
# 45570
# [262270, 86417, 45570]
# 0
# value is 45570
# It's not ok
# 1
# value is 6502
# No_duplication
# It's ok
# 6502
# 0
# value is 60890
# It's ok
# 60890
# 0
# value is 14607
# It's ok
# 14607
# 0
# value is 6502
# It's ok
# 6502
# [60890, 14607, 6502]
# 0
# value is 6502
# It's not ok
# 1
# value is 52012
# No_duplication
# It's ok
# 52012
# 0
# value is 312246
# It's ok
# 312246
# 0
# value is 100656
# It's ok
# 100656
# 0
# value is 52012
# It's ok
# 52012
# [312246, 100656, 52012]
# 0
# It's not ok
# 1
# It's not ok
# 2
# value is 62966
# No_duplication
# It's ok
# 62966
# 0
# value is 21558
# No_duplication
# It's ok
# 21558
# [62966, 21558]
# 0
# value is 62966
# It's not ok
# 1
# value is 62966
# It's not ok
# 2
# value is 62966
# It's not ok
# 3
# value is 32280
# No_duplication
# It's ok
# 32280
# 0
# value is 26662
# No_duplication
# It's ok
# 26662
# [32280, 26662]
# 0
# value is 26662
# It's not ok
# 1
# value is 26662
# It's not ok
# 2
# value is 26662
# It's not ok
# 3
# value is 9300
# No_duplication
# It's ok
# 9300
# 0
# value is 62966
# It's ok
# 62966
# 0
# value is 9300
# It's ok
# 9300
# [62966, 9300]
# 0
# value is 9300
# It's not ok
# 1
# value is 9300
# It's not ok
# 2
# value is 9300
# It's not ok
# 3
# value is 18823
# No_duplication
# It's ok
# 18823
# 0
# value is 62966
# It's ok
# 62966
# 0
# value is 18823
# It's ok
# 18823
# [62966, 18823]
# 0
# It's not ok
# 1
# It's not ok
# 2
# It's not ok
# 3
# value is 10496
# No_duplication
# It's ok
# 10496
# 0
# value is 10496
# It's ok
# 10496
# [10496]
# 0
# value is 10496
# It's not ok
# 1
# value is 8019
# No_duplication
# It's ok
# 8019
# 0
# value is 8019
# It's ok
# 8019
# [8019]
# 0
# It's not ok
# 1
# It's not ok
# 2
# value is 11368
# No_duplication
# It's ok
# 11368
# 0
# value is 3237
# No_duplication
# It's ok
# 3237
# [11368, 3237]
# 0
# value is 11368
# It's not ok
# 1
# value is 126
# No_duplication
# It's ok
# 126
# 0
# value is 126
# It's ok
# 126
# [126]
# 0
# value is 126
# It's not ok
# 1
# value is 126
# It's not ok
# 2
# value is 22091
# No_duplication
# It's ok
# 22091
# 0
# value is 2565
# No_duplication
# It's ok
# 2565
# [22091, 2565]
# 0
# value is 22091
# It's not ok
# 1
# value is 22091
# It's not ok
# 2
# value is 11037
# No_duplication
# It's ok
# 11037
# 0
# value is 7768
# No_duplication
# It's ok
# 7768
# [11037, 7768]
# 0
# It's not ok
# 1
# value is 24314
# No_duplication
# It's ok
# 24314
# 0
# value is 4451
# No_duplication
# It's ok
# 4451
# [24314, 4451]
# 0
# It's not ok
# 1
# It's not ok
# 2
# It's not ok
# 3
# value is 21035088
# No_duplication
# It's ok
# 21035088
# 0
# value is 95444
# No_duplication
# It's ok
# 95444
# [21035088, 95444]
# 0
# value is 95444
# It's not ok
# 1
# value is 95444
# It's not ok
# 2
# value is 11381
# No_duplication
# It's ok
# 11381
# 0
# value is 21035088
# It's ok
# 21035088
# 0
# value is 11381
# It's ok
# 11381
# [21035088, 11381]
# 0
# value is 21035088
# It's not ok
# 1
# value is 21035088
# It's not ok
# 2
# value is 21035088
# It's not ok
# 3
# value is 92339
# No_duplication
# It's ok
# 92339
# 0
# value is 92339
# It's ok
# 92339
# [92339]
# 0
# It's not ok
# 1
# It's not ok
# 2
# value is 1741278
# No_duplication
# It's ok
# 1741278
# 0
# value is 2915
# No_duplication
# It's ok
# 2915
# [1741278, 2915]
# 0
# value is 2915
# It's not ok
# 1
# value is 7
# No_duplication
# It's ok
# 7
# 0
# value is 1741278
# It's ok
# 1741278
# 0
# value is 7
# It's ok
# 7
# [1741278, 7]
# 0
# It's not ok
# 1
# It's not ok
# 2
# value is 548824
# No_duplication
# It's ok
# 548824
# 0
# value is 140629
# No_duplication
# It's ok
# 140629
# [548824, 140629]
# 0
# value is 140629
# It's not ok
# 1
# value is 140629
# It's not ok
# 2
# value is 140629
# It's not ok
# 3
# value is 40925
# No_duplication
# It's ok
# 40925
# 0
# value is 548824
# It's ok
# 548824
# 0
# value is 40925
# It's ok
# 40925
# [548824, 40925]
# 40925

# %%
#국내, 해외, 항공호텔, 전체카테고리
iOS_1 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/f6fCST7zQwalCMN1dpSuPw/a10587421w80067081p88823264/")
iOS_1.set_tab(5)
iOS_1.set_value([1,1,1,0,1])
iOS_1.get(1)
iOS_1.get(2)
iOS_1.get(3)
iOS_1.get(5)

#티몬 전체 카테고리
iOS_2 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/gmdw7utOS6OyMdXRs_jizg/a10587421w80067081p102782120/")
iOS_2.set_tab(1)
iOS_2.set_value(1)
iOS_2.get(1)

#국내딜, 해외딜, 전체딜
iOS_3 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/c9agY1srRx2PaD8JAkK0yw/a10587421w80067081p102782120/")
iOS_3.set_tab(3)
iOS_3.set_value([3,3,3])
iOS_3.get(1)
iOS_3.get(2)
iOS_3.get(3)
iOS_3.set_segment_url()
iOS_3.set_value([[3,3],[3,3],[3,3]])
iOS_3.get(1)
iOS_3.get(2)
iOS_3.get(3)

#항공검색 해외, 국내, 해외 -> 호텔메인, 해외 -> 국내메인
iOS_4 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/2K60xdJeT2isKsPe4tgpEQ/a10587421w80067081p88823264/%3F_u.date00%3D20170301%26_u.date01%3D20170320/")
iOS_4.set_tab(4)
iOS_4.set_value([2,2,[2,2],[2,2]])
iOS_4.get(1)
iOS_4.get(2)
iOS_4.get(3)
iOS_4.get(4)

#항공예약클릭 국내, 해외
iOS_5 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/_yDrAZzXTaeMOGlYkwqqbw/a10587421w80067081p102782120/%3F_u.date00%3D20170227%26_u.date01%3D20170305%26_.useg%3D%26_r.tabId%3D6028/")
iOS_5.set_tab(2)
iOS_5.set_value([1,1])
iOS_5.get(1)
iOS_5.get(2)

#부킹닷컴 큐레이션, 호텔배너, 주말특가, 해외호텔검색모듈
iOS_6 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/urNzazUpRDu9q-17-qtmtw/a10587421w80067081p102782120/%3F_u.date00%3D20170227%26_u.date01%3D20170305%26_.useg%3D/")
iOS_6.set_tab(4)
iOS_6.set_value([2,1,2,2])
iOS_6.get(1)
iOS_6.get(2)
iOS_6.get(3)
iOS_6.get(4)

#부킹닷컴 이벤트
iOS_7 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/qWyiPek-Tsqgkok-rZsIjA/a10587421w80067081p102782120/%3F_u.date00%3D20170227%26_u.date01%3D20170305%26_.useg%3D/")
iOS_7.set_tab(1)
iOS_7.set_value(2)
iOS_7.get(1)

#홈 -> 딜상세(국내), 해외, 여행카테고리숏컷
iOS_8 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/4rkbjB7zTGmgcRAlJaVzrg/a10587421w80067081p102782120/%3F_u.date00%3D20170227%26_u.date01%3D20170305%26_.useg%3D/")
iOS_8.set_tab(3)
iOS_8.set_value([2,[2,2],1])
iOS_8.get(1)
iOS_8.get(2)
iOS_8.get(3)

#홈 -> 콜렉션(국내), 해외
iOS_9 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/lUOk-ms-R966phrt04_yfA/a10587421w80067081p102782120/%3F_u.date00%3D20170227%26_u.date01%3D20170305%26_.useg%3D/")
iOS_9.set_tab(2)
iOS_9.set_value([2,[2,2]])
iOS_9.get(1)
iOS_9.get(2)
# Out:
# 0
# It's not ok
# 1
# value is 109489
# No_duplication
# It's ok
# 109489
# 0
# value is 109489
# It's ok
# 109489
# [109489]
# 0
# value is 109489
# It's not ok
# 1
# value is 109489
# It's not ok
# 2
# value is 59440
# No_duplication
# It's ok
# 59440
# 0
# value is 59440
# It's ok
# 59440
# [59440]
# 0
# value is 59440
# It's not ok
# 1
# value is 59440
# It's not ok
# 2
# value is 52435
# No_duplication
# It's ok
# 52435
# 0
# value is 52435
# It's ok
# 52435
# [52435]
# 0
# value is 52435
# It's not ok
# 1
# value is 191285
# No_duplication
# It's ok
# 191285
# 0
# value is 191285
# It's ok
# 191285
# [191285]
# 0
# It's not ok
# 1
# value is 1757208
# No_duplication
# It's ok
# 1757208
# 0
# value is 1757208
# It's ok
# 1757208
# [1757208]
# 0
# It's not ok
# 1
# value is 1261474
# No_duplication
# It's ok
# 1261474
# 0
# value is 162967
# No_duplication
# It's ok
# 162967
# 0
# value is 46674
# No_duplication
# It's ok
# 46674
# [1261474, 162967, 46674]
# 0
# value is 1261474
# It's not ok
# 1
# value is 383599
# No_duplication
# It's ok
# 383599
# 0
# value is 37039
# No_duplication
# It's ok
# 37039
# 0
# value is 6811
# No_duplication
# It's ok
# 6811
# [383599, 37039, 6811]
# 0
# value is 383599
# It's not ok
# 1
# value is 1577861
# No_duplication
# It's ok
# 1577861
# 0
# value is 199058
# No_duplication
# It's ok
# 199058
# 0
# value is 53416
# No_duplication
# It's ok
# 53416
# [1577861, 199058, 53416]
# 0
# value is 53416
# It's not ok
# 1
# value is 45570
# No_duplication
# It's ok
# 45570
# 0
# value is 262270
# It's ok
# 262270
# 0
# value is 86417
# It's ok
# 86417
# 0
# value is 45570
# It's ok
# 45570
# [262270, 86417, 45570]
# 0
# value is 45570
# It's not ok
# 1
# value is 6502
# No_duplication
# It's ok
# 6502
# 0
# value is 60890
# It's ok
# 60890
# 0
# value is 14607
# It's ok
# 14607
# 0
# value is 6502
# It's ok
# 6502
# [60890, 14607, 6502]
# 0
# value is 6502
# It's not ok
# 1
# value is 52012
# No_duplication
# It's ok
# 52012
# 0
# value is 312246
# It's ok
# 312246
# 0
# value is 100656
# It's ok
# 100656
# 0
# value is 52012
# It's ok
# 52012
# [312246, 100656, 52012]
# 0
# It's not ok
# 1
# value is 45057
# No_duplication
# It's ok
# 45057
# 0
# value is 17183
# No_duplication
# It's ok
# 17183
# [45057, 17183]
# 0
# value is 45057
# It's not ok
# 1
# value is 45057
# It's not ok
# 2
# value is 45057
# It's not ok
# 3
# value is 19088
# No_duplication
# It's ok
# 19088
# 0
# value is 15762
# No_duplication
# It's ok
# 15762
# [19088, 15762]
# 0
# value is 15762
# It's not ok
# 1
# value is 6695
# No_duplication
# It's ok
# 6695
# 0
# value is 45057
# It's ok
# 45057
# 0
# value is 6695
# It's ok
# 6695
# [45057, 6695]
# 0
# value is 6695
# It's not ok
# 1
# value is 12485
# No_duplication
# It's ok
# 12485
# 0
# value is 45057
# It's ok
# 45057
# 0
# value is 12485
# It's ok
# 12485
# [45057, 12485]
# 0
# It's not ok
# 1
# value is 10496
# No_duplication
# It's ok
# 10496
# 0
# value is 10496
# It's ok
# 10496
# [10496]
# 0
# value is 10496
# It's not ok
# 1
# value is 10496
# It's not ok
# 2
# value is 8019
# No_duplication
# It's ok
# 8019
# 0
# value is 8019
# It's ok
# 8019
# [8019]
# 0
# It's not ok
# 1
# It's not ok
# 2
# value is 11368
# No_duplication
# It's ok
# 11368
# 0
# value is 3237
# No_duplication
# It's ok
# 3237
# [11368, 3237]
# 0
# value is 11368
# It's not ok
# 1
# value is 126
# No_duplication
# It's ok
# 126
# 0
# value is 126
# It's ok
# 126
# [126]
# 0
# value is 126
# It's not ok
# 1
# value is 126
# It's not ok
# 2
# value is 22091
# No_duplication
# It's ok
# 22091
# 0
# value is 2565
# No_duplication
# It's ok
# 2565
# [22091, 2565]
# 0
# value is 22091
# It's not ok
# 1
# value is 22091
# It's not ok
# 2
# value is 22091
# It's not ok
# 3
# value is 11037
# No_duplication
# It's ok
# 11037
# 0
# value is 7768
# No_duplication
# It's ok
# 7768
# [11037, 7768]
# 0
# It's not ok
# 1
# It's not ok
# 2
# value is 24314
# No_duplication
# It's ok
# 24314
# 0
# value is 4451
# No_duplication
# It's ok
# 4451
# [24314, 4451]
# 0
# It's not ok
# 1
# It's not ok
# 2
# value is 21035088
# No_duplication
# It's ok
# 21035088
# 0
# value is 95444
# No_duplication
# It's ok
# 95444
# [21035088, 95444]
# 0
# value is 95444
# It's not ok
# 1
# value is 11381
# No_duplication
# It's ok
# 11381
# 0
# value is 21035088
# It's ok
# 21035088
# 0
# value is 11381
# It's ok
# 11381
# [21035088, 11381]
# 0
# value is 21035088
# It's not ok
# 1
# value is 92339
# No_duplication
# It's ok
# 92339
# 0
# value is 92339
# It's ok
# 92339
# [92339]
# 0
# It's not ok
# 1
# value is 1741278
# No_duplication
# It's ok
# 1741278
# 0
# value is 2915
# No_duplication
# It's ok
# 2915
# [1741278, 2915]
# 0
# value is 2915
# It's not ok
# 1
# value is 7
# No_duplication
# It's ok
# 7
# 0
# value is 1741278
# It's ok
# 1741278
# 0
# value is 7
# It's ok
# 7
# [1741278, 7]
# 7

# %%
# 카테고리 국내, 해외, 항공호텔, 전체
PC_1 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/RFQ6OlJDT5-6MMKnjtJkcA/a10587421w80067081p84826225/")
PC_1.set_tab(4)
PC_1.set_value([1,1,[2,2],2])
PC_1.get(1)
PC_1.get(3)
PC_1.get_percent(1)
PC_1.get(2)
PC_1.get(4)
PC_1.get_percent(1)

# 티몬 전체 카테고리
PC_2 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/ZcNefO8cTRe75IKFbPcCWw/a10587421w80067081p84826225/%3F_.useg%3D/")
PC_2.set_tab(1)
PC_2.set_value(1)
PC_2.get(1)

# 여행 전체, 국내, 해외딜
PC_3 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/hRoEL4w4RCyYpcmhDbvgWw/a10587421w80067081p84826225/%3F_.useg%3D/")
PC_3.set_tab(3)
PC_3.set_value([3,3,3])
PC_3.get(1)
PC_3.get(2)
PC_3.get(3)
PC_3.set_segment_url()
PC_3.set_value([[3,3],[3,3],[3,3]])
PC_3.get(1)
PC_3.get(2)
PC_3.get(3)

# 항공검색 국내, 해외
PC_4 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/KkWuVj5-SCOH7ddtrf4bOA/a10587421w80067081p84826225/")
PC_4.set_tab(2)
PC_4.set_value([2,2])
PC_4.get(1)
PC_4.get(2)

# 예약클릭 국내, 해외
PC_5 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/YspUfeZLQ7KyhFzRxehRcQ/a10587421w80067081p84826225/%3F_.useg%3D/")
PC_5.set_tab(2)
PC_5.set_value([2,2])
PC_5.get(1)
PC_5.get(2)

# 부킹닷컴 큐레이션, 해외호텔 카테고리, 주말특가
PC_6 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/jQo-QVnGRrG1Y_Dtaoz0FQ/a10587421w80067081p84826225/%3F_.useg%3D/")
PC_6.set_tab(3)
PC_6.set_value([2,1,2])
PC_6.get(1)
PC_6.get(2)
PC_6.get(3)

# 부킹닷컴 이벤트
PC_7 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/K68VmWT0QxSxn2j0wohK4A/a10587421w80067081p84826225/%3F_.useg%3D/")
PC_7.set_tab(1)
PC_7.set_value(1)
PC_7.get(1)
# Out:
# 0
# It's not ok
# 1
# value is 186207
# No_duplication
# It's ok
# 186207
# 0
# value is 186207
# It's ok
# 186207
# [186207]
# 0
# It's not ok
# 1
# It's not ok
# 2
# value is 4497
# No_duplication
# It's ok
# 4497
# 0
# value is 67893
# It's ok
# 67893
# 0
# value is 4497
# It's ok
# 4497
# [67893, 4497]
# 0.61
# 0
# value is 67893
# It's not ok
# 1
# value is 90932
# No_duplication
# It's ok
# 90932
# 0
# value is 90932
# It's ok
# 90932
# [90932]
# 0
# value is 90932
# It's not ok
# 1
# value is 90932
# It's not ok
# 2
# value is 302935
# No_duplication
# It's ok
# 302935
# 0
# value is 4497
# No_duplication
# It's ok
# 4497
# [302935, 4497]
# 0.38
# 0
# It's not ok
# 1
# value is 954900
# No_duplication
# It's ok
# 954900
# 0
# value is 954900
# It's ok
# 954900
# [954900]
# 0
# It's not ok
# 1
# value is 988871
# No_duplication
# It's ok
# 988871
# 0
# value is 57455
# No_duplication
# It's ok
# 57455
# 0
# value is 19157
# No_duplication
# It's ok
# 19157
# [988871, 57455, 19157]
# 0
# value is 988871
# It's not ok
# 1
# value is 731677
# No_duplication
# It's ok
# 731677
# 0
# value is 42859
# No_duplication
# It's ok
# 42859
# 0
# value is 14751
# No_duplication
# It's ok
# 14751
# [731677, 42859, 14751]
# 0
# value is 731677
# It's not ok
# 1
# value is 286354
# No_duplication
# It's ok
# 286354
# 0
# value is 14652
# No_duplication
# It's ok
# 14652
# 0
# value is 4290
# No_duplication
# It's ok
# 4290
# [286354, 14652, 4290]
# 0
# value is 4290
# It's not ok
# 1
# value is 4290
# It's not ok
# 2
# value is 4290
# It's not ok
# 3
# value is 4290
# It's not ok
# 4
# value is 4290
# It's not ok
# 5
# value is 18887
# No_duplication
# It's ok
# 18887
# 0
# value is 81887
# It's ok
# 81887
# 0
# value is 25969
# It's ok
# 25969
# 0
# value is 18887
# It's ok
# 18887
# [81887, 25969, 18887]
# 0
# value is 18887
# It's not ok
# 1
# value is 18887
# It's not ok
# 2
# value is 18887
# It's not ok
# 3
# value is 14549
# No_duplication
# It's ok
# 14549
# 0
# value is 62437
# It's ok
# 62437
# 0
# value is 20155
# It's ok
# 20155
# 0
# value is 14549
# It's ok
# 14549
# [62437, 20155, 14549]
# 0
# value is 14549
# It's not ok
# 1
# value is 14549
# It's not ok
# 2
# value is 14549
# It's not ok
# 3
# value is 14549
# It's not ok
# 4
# value is 14549
# It's not ok
# 5
# value is 4221
# No_duplication
# It's ok
# 4221
# 0
# value is 21509
# It's ok
# 21509
# 0
# value is 5741
# It's ok
# 5741
# 0
# value is 4221
# It's ok
# 4221
# [21509, 5741, 4221]
# 0
# It's not ok
# 1
# value is 41525
# No_duplication
# It's ok
# 41525
# 0
# value is 21655
# No_duplication
# It's ok
# 21655
# [41525, 21655]
# 0
# value is 41525
# It's not ok
# 1
# value is 28703
# No_duplication
# It's ok
# 28703
# 0
# value is 17868
# No_duplication
# It's ok
# 17868
# [28703, 17868]
# 0
# It's not ok
# 1
# It's not ok
# 2
# value is 34000
# No_duplication
# It's ok
# 34000
# 0
# value is 5138
# No_duplication
# It's ok
# 5138
# [34000, 5138]
# 0
# value is 34000
# It's not ok
# 1
# value is 34000
# It's not ok
# 2
# value is 28383
# No_duplication
# It's ok
# 28383
# 0
# value is 5212
# No_duplication
# It's ok
# 5212
# [28383, 5212]
# 0
# It's not ok
# 1
# value is 9424
# No_duplication
# It's ok
# 9424
# 0
# value is 3804
# No_duplication
# It's ok
# 3804
# [9424, 3804]
# 0
# value is 9424
# It's not ok
# 1
# value is 4497
# No_duplication
# It's ok
# 4497
# 0
# value is 4497
# It's ok
# 4497
# [4497]
# 0
# value is 4497
# It's not ok
# 1
# value is 4497
# It's not ok
# 2
# value is 4497
# It's not ok
# 3
# value is 21605
# No_duplication
# It's ok
# 21605
# 0
# value is 1223
# No_duplication
# It's ok
# 1223
# [21605, 1223]
# 0
# It's not ok
# 1
# value is 5775
# No_duplication
# It's ok
# 5775
# 0
# value is 5775
# It's ok
# 5775
# [5775]
# 5775

# %%
#국내카테고리, 해외, 항공호텔, 전체
Mo_1 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/V-T6iNbTQWi5USC2dSi5tA/a10587421w80067081p89357101/")
Mo_1.set_tab(5)
Mo_1.set_value([1,1,1,0,2])

#티몬 홈 전체
Mo_2 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/zoovm6xETN-Cd6JF9s2_hQ/a10587421w80067081p89357101/")
Mo_2.set_tab(1)
Mo_2.set_value(1)
Mo_2.get(1)

#여행딜 전체, 국내, 해외
Mo_3 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/upJUz96ERVGUIE2WWd8Tgg/a10587421w80067081p89357101/")
Mo_3.set_tab(3)
Mo_3.set_value([3,3,3])
Mo_3.get(1)
Mo_3.get(2)
Mo_3.get(3)
Mo_3.set_segment_url()
Mo_3.set_value([[3,3],[3,3],[3,3]])
Mo_3.get(1)
Mo_3.get(2)
Mo_3.get(3)

#항공검색 해외, 국내, 해외->호텔, 해외->국내
Mo_4 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/7aMTsZECQu2GVnxwp3IXRg/a10587421w80067081p89357101/")
Mo_4.set_tab(4)
Mo_4.set_value([2,2,[2,2],[2,2]])
Mo_4.get(1)
Mo_4.get(2)
Mo_4.get(3)
Mo_4.get(4)

#항공예약클릭 국내, 해외
Mo_5 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/Shs74NpmR1Wcy5isHt_ZGA/a10587421w80067081p89357101/")
Mo_5.set_tab(2)
Mo_5.set_value([1,1])
Mo_5.get(1)
Mo_5.get(2)

#부킹닷컴 큐레이션, 호텔메인
Mo_6 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/W52iAReKSeydMYwmwkpBbA/a10587421w80067081p89357101/")
Mo_6.set_tab(2)
Mo_6.set_value([2,2])
Mo_6.get(1)
Mo_6.get(2)

#부킹닷컴 이벤트
Mo_7 = GA("https://analytics.google.com/analytics/web/?authuser=0#my-reports/gY8HkfiiQaqkTZOucG8YFQ/a10587421w80067081p89357101/")
Mo_7.set_tab(1)
Mo_7.set_value(2)
Mo_7.get(1)
# Out:
# 0
# It's not ok
# 1
# value is 585261
# No_duplication
# It's ok
# 585261
# 0
# value is 585261
# It's ok
# 585261
# [585261]
# 0
# It's not ok
# 1
# value is 1466935
# No_duplication
# It's ok
# 1466935
# 0
# value is 70428
# No_duplication
# It's ok
# 70428
# 0
# value is 15489
# No_duplication
# It's ok
# 15489
# [1466935, 70428, 15489]
# 0
# value is 1466935
# It's not ok
# 1
# value is 1165222
# No_duplication
# It's ok
# 1165222
# 0
# value is 56744
# No_duplication
# It's ok
# 56744
# 0
# value is 12970
# No_duplication
# It's ok
# 12970
# [1165222, 56744, 12970]
# 0
# value is 1165222
# It's not ok
# 1
# value is 315722
# No_duplication
# It's ok
# 315722
# 0
# value is 13774
# No_duplication
# It's ok
# 13774
# 0
# value is 2522
# No_duplication
# It's ok
# 2522
# [315722, 13774, 2522]
# 0
# value is 2522
# It's not ok
# 1
# value is 15394
# No_duplication
# It's ok
# 15394
# 0
# value is 77813
# It's ok
# 77813
# 0
# value is 22823
# It's ok
# 22823
# 0
# value is 15394
# It's ok
# 15394
# [77813, 22823, 15394]
# 0
# value is 15394
# It's not ok
# 1
# value is 12886
# No_duplication
# It's ok
# 12886
# 0
# value is 61724
# It's ok
# 61724
# 0
# value is 18965
# It's ok
# 18965
# 0
# value is 12886
# It's ok
# 12886
# [61724, 18965, 12886]
# 0
# value is 12886
# It's not ok
# 1
# value is 2511
# No_duplication
# It's ok
# 2511
# 0
# value is 16832
# It's ok
# 16832
# 0
# value is 3873
# It's ok
# 3873
# 0
# value is 2511
# It's ok
# 2511
# [16832, 3873, 2511]
# 0
# It's not ok
# 1
# value is 18835
# No_duplication
# It's ok
# 18835
# 0
# value is 4423
# No_duplication
# It's ok
# 4423
# [18835, 4423]
# 0
# value is 18835
# It's not ok
# 1
# value is 7945
# No_duplication
# It's ok
# 7945
# 0
# value is 4053
# No_duplication
# It's ok
# 4053
# [7945, 4053]
# 0
# value is 4053
# It's not ok
# 1
# value is 2027
# No_duplication
# It's ok
# 2027
# 0
# value is 18835
# It's ok
# 18835
# 0
# value is 2027
# It's ok
# 2027
# [18835, 2027]
# 0
# value is 2027
# It's not ok
# 1
# value is 4577
# No_duplication
# It's ok
# 4577
# 0
# value is 18835
# It's ok
# 18835
# 0
# value is 4577
# It's ok
# 4577
# [18835, 4577]
# 0
# It's not ok
# 1
# value is 1030
# No_duplication
# It's ok
# 1030
# 0
# value is 1030
# It's ok
# 1030
# [1030]
# 0
# value is 1030
# It's not ok
# 1
# value is 1835
# No_duplication
# It's ok
# 1835
# 0
# value is 1835
# It's ok
# 1835
# [1835]
# 0
# It's not ok
# 1
# value is 6399
# No_duplication
# It's ok
# 6399
# 0
# value is 970
# No_duplication
# It's ok
# 970
# [6399, 970]
# 0
# value is 6399
# It's not ok
# 1
# value is 3038
# No_duplication
# It's ok
# 3038
# 0
# value is 1802
# No_duplication
# It's ok
# 1802
# [3038, 1802]
# 0
# It's not ok
# 1
# value is 733
# No_duplication
# It's ok
# 733
# 0
# value is 148
# No_duplication
# It's ok
# 148
# [733, 148]
# [733, 148]
