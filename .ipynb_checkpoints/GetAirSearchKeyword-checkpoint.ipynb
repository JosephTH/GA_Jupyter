# %%
import requests

# %%
payload = {"platform":"all","statType":"sum","searchType":"like","startDate":"2017-04-23T15:00:00.000Z",\
           "endDate":"2017-04-25T15:00:00.000Z","sortField":"search_count","sortType":"desc","rankCount":"400",\
           "startDealNumber":0,"endDealNumber":200,"catDepth1No":"15000000","catDepth2No":"","catDepth3No":"","catDepth4No":"",\
           "dateCondition":"dt BETWEEN '2017-04-24' AND '2017-04-26'"}
headers = {
    'Host': 'searchadmin.tmon.co.kr',
    'Connection': 'keep-alive',
    'Content-Length': '369',
    'Accept': 'application/json, text/plain, */*',
    'Origin': 'http://searchadmin.tmon.co.kr',
  #  'User-Agent': ['Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36
    'Content-Type': 'application/json;charset=UTF-8',
    'Referer': 'http://searchadmin.tmon.co.kr/totalKeywordRank',
    'Accept-Encoding': 'gzip',
    'Accept-Language': 'ko-KR,ko;q=0.8,en-US;q=0.6,en;q=0.4',
    'Cookie': 'CKEY=...; JSESSIONID=1C9028AE43348FA28F6BD97D8FF3DC50'
}
doc = requests.post("http://searchadmin.tmon.co.kr/totalKeywordRank/keywords", data= payload, headers=headers)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\users\joseph_th\appdata\local\continuum\miniconda3\envs\py3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# c:\users\joseph_th\appdata\local\continuum\miniconda3\envs\py3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#
# c:\users\joseph_th\appdata\local\continuum\miniconda3\envs\py3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     742     addrlist = []
# ...

# %%
doc.text
# Out:
# '<!doctype html>\n<html lang="ko">\n<head>\n\t<meta charset="utf-8">\n\t<title>핵심구조개선 New Admin 페이지</title>\n\t<link rel="shortcut icon" href="/static/img/favicon.ico"/>\n\t<script type="text/javascript" src="/static/js/jquery-1.7.2.min.js"></script>\n\t<script type="text/javascript" src="/static/js/jquery.number_format.js"></script>\n\t<script type="text/javascript" src="/static/js/admin.js"></script>\n\n\t<style type="text/css">\n\t::selection{ background-color: #E13300; color: white; }\n\t::moz-selection{ background-color: #E13300; color: white; }\n\t::webkit-selection{ background-color: #E13300; color: white; }\n\n\tbody {\n\t\tbackground-color: #fff;\n\t\tfont: 13px/20px normal Helvetica, Arial, sans-serif;\n\t\tcolor: #4F5155;\n        position:relative;\n\t}\n\n\ta {\n\t\tcolor: #003399;\n\t\tbackground-color: transparent;\n\t\tfont-weight: normal;\n\t}\n\n\th1 {\n\t\tcolor: #444;\n\t\tbackground-color: transparent;\n\t\tborder-bottom: 1px solid #D0D0D0;\n\t\tfont-size: 19px;\
# ...
